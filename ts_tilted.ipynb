# %%
from experiment.experiment import Experiment
from envs.bandits import BanditFactory
from algorithms.algorithms import AlgorithmFactory

# %%
from algorithms.uniform import Uniform
from algorithms.ecolog import ECOLOG
from algorithms.max_uncertainty import MaxUncertainty
from algorithms.lucb import LUCB
from algorithms.ecots import EcoTS
from algorithms.toptwots import TopTwoTS

from envs.guassian_bandit import GuassianBandit
from envs.adv4_bandit import Adv4Bandit
from envs.adv_ttts import AdvTTTS

# %%
uniform_factory = AlgorithmFactory(Uniform, "uniform", [])
ecots_factory_001 = AlgorithmFactory(EcoTS, "ecots", ["param_norm_ub"], inflation=1)
toptwots_factory_01 = AlgorithmFactory(
    TopTwoTS, "toptwots", ["param_norm_ub"], inflation=1
)
maxuncertainty_factory = AlgorithmFactory(
    MaxUncertainty, "max_uncertainty", ["param_norm_ub"]
)
ecolog_factory = AlgorithmFactory(ECOLOG, "ecolog", ["param_norm_ub"], inflation=1)

guassian_factory = BanditFactory(
    GuassianBandit,
    "guassian",
    n_arms=20,
    n_contexts=20,
    d=15,
    fit_into_unit_ball=True,
)
ttts_breaker_factory = BanditFactory(
    AdvTTTS,
    "TTSBreaker",
    n_arms=3,
    n_contexts=1,
    d=2,
)
adv_factory = BanditFactory(
    Adv4Bandit,
    "needle",
    n_arms=70,
    n_contexts=400,
    d=30,
    fit_into_unit_ball=True,
)
experiment = Experiment(
    [
        ttts_breaker_factory,
        # ttts_breaker_factory,
        # adv_factory,
    ],
    [
        # uniform_factory,
        maxuncertainty_factory,
        # ecots_factory_001,
        toptwots_factory_01,
        # ecolog_factory,
    ],
)

# %%
from experiment.simple_regret import SimpleRegret
from experiment.action_tracker import ActionTracker
from experiment.theta_tracker import ThetaTracker

simple_regret_callback = SimpleRegret(interval=100)
action_tracker_callback = ActionTracker()
theta_tracker_callback = ThetaTracker(interval=10, style="together")

experiment.add_callback(simple_regret_callback)
experiment.add_callback(action_tracker_callback)
experiment.add_callback(theta_tracker_callback)

# %%
experiment.interact(n_steps=1000, n_runs=50, log_progress=True)
# Out:
# Finished run 1 of 50 for TTSBreaker in 1.1126959323883057 seconds
# Finished run 2 of 50 for TTSBreaker in 2.261427164077759 seconds
# Finished run 3 of 50 for TTSBreaker in 3.3570430278778076 seconds
# Finished run 4 of 50 for TTSBreaker in 4.431848049163818 seconds
# Finished run 5 of 50 for TTSBreaker in 5.495661973953247 seconds
# Finished run 6 of 50 for TTSBreaker in 6.542754888534546 seconds
# Finished run 7 of 50 for TTSBreaker in 7.541698932647705 seconds
# Finished run 8 of 50 for TTSBreaker in 8.539549112319946 seconds
# Finished run 9 of 50 for TTSBreaker in 9.53457498550415 seconds
# Finished run 10 of 50 for TTSBreaker in 10.531124830245972 seconds
# Finished run 11 of 50 for TTSBreaker in 11.528210878372192 seconds
# Finished run 12 of 50 for TTSBreaker in 12.519176006317139 seconds
# Finished run 13 of 50 for TTSBreaker in 13.516685009002686 seconds
# Finished run 14 of 50 for TTSBreaker in 14.517252922058105 seconds
# Finished run 15 of 50 for TTSBreaker in 15.515358924865723 seconds
# Finished run 16 of 50 for TTSBreaker in 16.510426998138428 seconds
# Finished run 17 of 50 for TTSBreaker in 17.509819984436035 seconds
# Finished run 18 of 50 for TTSBreaker in 18.50279211997986 seconds
# Finished run 19 of 50 for TTSBreaker in 19.495128870010376 seconds
# Finished run 20 of 50 for TTSBreaker in 20.484029054641724 seconds
# Finished run 21 of 50 for TTSBreaker in 21.4774329662323 seconds
# Finished run 22 of 50 for TTSBreaker in 22.472725868225098 seconds
# Finished run 23 of 50 for TTSBreaker in 23.461835861206055 seconds
# Finished run 24 of 50 for TTSBreaker in 24.448378086090088 seconds
# Finished run 25 of 50 for TTSBreaker in 25.46718192100525 seconds
# Finished run 26 of 50 for TTSBreaker in 26.46597385406494 seconds
# Finished run 27 of 50 for TTSBreaker in 27.453947067260742 seconds
# Finished run 28 of 50 for TTSBreaker in 28.469162940979004 seconds
# Finished run 29 of 50 for TTSBreaker in 29.5378201007843 seconds
# Finished run 30 of 50 for TTSBreaker in 30.536463022232056 seconds
# Finished run 31 of 50 for TTSBreaker in 31.527326822280884 seconds
# Finished run 32 of 50 for TTSBreaker in 32.542572021484375 seconds
# Finished run 33 of 50 for TTSBreaker in 33.54301881790161 seconds
# Finished run 34 of 50 for TTSBreaker in 34.53013801574707 seconds
# Finished run 35 of 50 for TTSBreaker in 35.52718997001648 seconds
# Finished run 36 of 50 for TTSBreaker in 36.526835203170776 seconds
# Finished run 37 of 50 for TTSBreaker in 37.51859498023987 seconds
# Finished run 38 of 50 for TTSBreaker in 38.511621952056885 seconds
# Finished run 39 of 50 for TTSBreaker in 39.50198006629944 seconds
# Finished run 40 of 50 for TTSBreaker in 40.4966459274292 seconds
# Finished run 41 of 50 for TTSBreaker in 41.4954879283905 seconds
# Finished run 42 of 50 for TTSBreaker in 42.49063014984131 seconds
# Finished run 43 of 50 for TTSBreaker in 43.48538303375244 seconds
# Finished run 44 of 50 for TTSBreaker in 44.48338794708252 seconds
# Finished run 45 of 50 for TTSBreaker in 45.47290897369385 seconds
# Finished run 46 of 50 for TTSBreaker in 46.46753978729248 seconds
# Finished run 47 of 50 for TTSBreaker in 47.459563970565796 seconds
# Finished run 48 of 50 for TTSBreaker in 48.45789694786072 seconds
# Finished run 49 of 50 for TTSBreaker in 49.45564413070679 seconds
# Finished run 50 of 50 for TTSBreaker in 50.45170497894287 seconds
# /Users/sarb/Desktop/ttts/experiment/theta_tracker.py:112: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(

# %%
from math import sqrt

a = sqrt(1.0 - (0.99999) ** 2)
a
# Out:
# 0.004472124774634615
